# %%
import os
import zipfile
import numpy as np
from ultralytics import YOLO
import torch
import cv2 as cv

# %%
# set the device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Current device:', device)

if device.type == 'cuda':
    print('GPU Name:', torch.cuda.get_device_name(0))
    print('Total GPU Memory:', round(torch.cuda.get_device_properties(0).total_memory/1024**3,1), 'GB')
# Out:
# Current device: cuda
# GPU Name: NVIDIA GeForce GTX 1650 with Max-Q Design
# Total GPU Memory: 4.0 GB

# %%
model = YOLO("yolov8s-cls.pt")
model.to(device)

data_dir=r"C:\Users\NSagi\Music\Desktop\2023-24_Fall\EEE-443\Term_Project\Cats_and_Doggs_Classifiers\PetImages"
results = model.train(data=data_dir, epochs=10, batch=5)
# Out:
# New https://pypi.org/project/ultralytics/8.0.231 available  Update with 'pip install -U ultralytics'
# ...

# %%
model_path = os.path.join('.', 'runs', 'classify', 'train7', 'weights', 'last.pt')

#test_image_path = r"C:\Users\NSagi\Music\Desktop\2023-24_Fall\EEE-443\Term_Project\Cats_and_Doggs_Classifiers\PetImages\train\Dog\147.jpg"

# choose a random image from C:\Users\NSagi\Music\Desktop\2023-24_Fall\EEE-443\Term_Project\Cats_and_Doggs_Classifiers\random_test\dogs

my_random_dog_image = np.random.choice(os.listdir(r"C:\Users\NSagi\Music\Desktop\2023-24_Fall\EEE-443\Term_Project\Cats_and_Doggs_Classifiers\random_test\dogs"))
my_random_dog_image_path = os.path.join(r"C:\Users\NSagi\Music\Desktop\2023-24_Fall\EEE-443\Term_Project\Cats_and_Doggs_Classifiers\random_test\dogs", my_random_dog_image)

my_random_cat_image = np.random.choice(os.listdir(r"C:\Users\NSagi\Music\Desktop\2023-24_Fall\EEE-443\Term_Project\Cats_and_Doggs_Classifiers\random_test\cats"))
my_random_cat_image_path = os.path.join(r"C:\Users\NSagi\Music\Desktop\2023-24_Fall\EEE-443\Term_Project\Cats_and_Doggs_Classifiers\random_test\cats", my_random_cat_image)

# randomly choose a dog or a cat
if np.random.rand() > 0.5:
    test_image_path = my_random_dog_image_path
else:
    test_image_path = my_random_cat_image_path

# Load a model
model = YOLO(model_path)  # load a custom model

# results = model.predict(source=0, show=True)
results = model.predict(source=test_image_path, show=True)



cv.waitKey(0)
# Out:
# image 1/1 C:\Users\NSagi\Music\Desktop\2023-24_Fall\EEE-443\Term_Project\Cats_and_Doggs_Classifiers\random_test\cats\843.jpg: 224x224 Cat 1.00, Dog 0.00, 13.7ms
# Speed: 2.0ms preprocess, 13.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# -1
